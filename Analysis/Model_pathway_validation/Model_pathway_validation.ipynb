# %% [markdown]
# ## Reading the Aspergillus niger model - ATCC 1015 iJB1325

# %% [markdown]
# ### Import the required libraries and the model.

# %%
from cobra.io import read_sbml_model
from cobra import Reaction, Metabolite
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline


model = read_sbml_model('2018_ATCC1015_GSM_iJB1325.xml') #The model is refered from (Brandl, J., Aguilar-Pontes, M. V., Schape, P., Norregaard, A., Arvas, M., Ram, A. F. J., Meyer, V., Tsang, A., de Vries, R. P., & Andersen, M. R. (2018). A community-driven reconstruction of the Aspergillus niger metabolic network. Fungal Biology and Biotechnology, 5, 16. )

# %% [markdown]
# ### Verify the avialibility of the pathway in the model

# %% [markdown]
# #### 6-MSA synthesis

# %%
#6-MSA synthesis
model.reactions.r2000
# Out:
# <Reaction r2000 at 0x20be2aa7280>

# %%
model.reactions.r2000.compartments
# Out:
# {'c'}

# %% [markdown]
# #### m-cresol synthesis

# %%
#m-Cresol synthesis
model.reactions.r2001
# Out:
# <Reaction r2001 at 0x20be2ac6b30>

# %%
model.reactions.r2001.compartments
# Out:
# {'c'}

# %% [markdown]
# #### Toluquinol synthesis

# %%
#Toluquinol synthesis
model.reactions.r2002
# Out:
# <Reaction r2002 at 0x20be2ac6c50>

# %%
model.reactions.r2002.compartments
# Out:
# {'c'}

# %% [markdown]
# #### Tolue E synthesis

# %%
model.reactions.r2003
# Out:
# <Reaction r2003 at 0x20be2ac6ce0>

# %%
model.reactions.r2003.compartments
# Out:
# {'c'}

# %% [markdown]
# #### Tolue K synthesis

# %%
model.reactions.NE7
# Out:
# <Reaction NE7 at 0x20be2ac7610>

# %%
model.reactions.NE7.compartments
# Out:
# {'c'}

# %% [markdown]
# #### 7-deacetylyanuthone A synthesis

# %%
model.reactions.r2005
# Out:
# <Reaction r2005 at 0x20be2aa6200>

# %%
model.reactions.r2005.compartments
# Out:
# {'c'}

# %% [markdown]
# #### 22-deacetylyanuthone A synthesis

# %%
model.reactions.r2006
# Out:
# <Reaction r2006 at 0x20be2ac7580>

# %%
model.reactions.r2006.compartments
# Out:
# {'c'}

# %% [markdown]
# #### Yanuthone E synthesis

# %%
model.reactions.r2007
# Out:
# <Reaction r2007 at 0x20be2ac7910>

# %%
model.reactions.r2007.compartments
# Out:
# {'c'}

# %% [markdown]
# #### Yanuthone D synthesis

# %%
model.reactions.r2008
# Out:
# <Reaction r2008 at 0x20be2ae8310>

# %%
model.reactions.r2008.compartments
# Out:
# {'c'}

# %% [markdown]
# ## Metabolic pathway visualizations with Escher

# %% [markdown]
# ### Construction of Yanuthone D synthesis

# %%
import cobra
from cobra import Model,Reaction, Metabolite
import d3flux as d3f
from d3flux.core.flux_layouts import render_model

from jinja2 import Template

custom_css = \
"""
{% for item in items %}
text#{{ item }} {
    font-weight: 900;
}
{% endfor %}
text.cofactor {
    fill: #778899;
}
"""

css = Template(custom_css).render(items=['6MSA', 'ACCOA', 'MALCOA', "MCRE", "TOLU", "TOLUEE", 
                                         "TOLUEK", "7DEACYANUA", "22DEAYANUA", "YANUE", "YANUD"])

# %% [markdown]
# #### Compilation of reactions in the Yanuthone D synthesis

# %%
_6_MSA_synthesis = model.reactions.r2000 #6-MSA syntheis
m_cresol_synthesis = model.reactions.r2001 #m-cresol syntheis
Toluquinol_synthesis = model.reactions.r2002 #Toluquinol synthesis
TolueE_synthesis = model.reactions.r2003 #Tolue E synthesis
TolueK_synthesis = model.reactions.NE7 #Tolue K synthesis
_7_deacetylyanuthone_A_synthesis = model.reactions.r2005 #7-deacetylyanuthone A synthesis
_22_deacetylyanuthone_A_synthesis  = model.reactions.r2006 #22-deacetylyanuthone A synthesis
Yanuthone_E_synthesis = model.reactions.r2007 #Yanothone E synthesis    
Yanuthone_D_synthesis = model.reactions.r2008 #Yanthone D synthesis

# %% [markdown]
# #### Addition of reactions in the Yanuthone D pathway

# %%
Yanuthone_D_pathway = Model('simple_model')

Yanuthone_D_pathway.add_reactions([_6_MSA_synthesis])
Yanuthone_D_pathway.add_reactions([m_cresol_synthesis])
Yanuthone_D_pathway.add_reactions([Toluquinol_synthesis])
Yanuthone_D_pathway.add_reactions([TolueE_synthesis])
Yanuthone_D_pathway.add_reactions([TolueK_synthesis])
Yanuthone_D_pathway.add_reactions([_7_deacetylyanuthone_A_synthesis])
Yanuthone_D_pathway.add_reactions([_22_deacetylyanuthone_A_synthesis])
Yanuthone_D_pathway.add_reactions([Yanuthone_E_synthesis])
Yanuthone_D_pathway.add_reactions([Yanuthone_D_synthesis])

#cobra.io.save_json_model(Yanuthone_D_pathway, filename= "Yanuthone_D_pathway.json")

# %% [markdown]
# #### Update list of common cofactors

# %%
#model = cobra.io.load_json_model("Yanuthone_D_pathway.json")
#common_cofactors = ['coa', 'nadph', 'nadp', 'co2', 'h2o', 'o2', 'FPP', "PPI"]
#d3f.update_cofactors(model, common_cofactors)

# %%
model = cobra.io.load_json_model("Yanuthone_D_pathway.json")

# %% [markdown]
# #### Yanuthone D pathway visualization

# %%
from markupsafe import soft_unicode

# %%
html = d3f.flux_map(model, custom_css=css, figsize=(600, 1200), default_flux_width=1.5, fontsize= 8,
                    hide_unused_cofactors = True)
html
# Out:
# <div id="d3flux002">
#
# </div>
# <div id="d3flux002_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux002model = {"metabolites": [{"id": "6MSA", "name": "6-Methylsalicylic acid", "compartment": "c", "charge": 0, "formula": "C8H8O3", "notes": {"map_info": {"display_name": "6MSA", "align": "center"}}, "annotation": {"chebi": "CHEBI:17637", "inchi": "InChI=1S/C8H8O3/c1-5-3-2-4-6(9)7(5)8(10)11/h2-4,9H,1H3,(H,10,11)", "kegg.compound": "C02657"}}, {"id": "ACCOA", "name": "Acetyl coenzyme A", "compartment": "c", "charge": 0, "formula": "C23H38N7O17P3S", "notes": {"map_info": {"display_name": "Acetyl coenzyme A", "align": "center"}}, "annotation": {"chebi": "CHEBI:15351", "inchi": "InChI=1S/C23H38N7O17P3S/c1-12(31)51-7-6-25-14(32)4-5-26-21(35)18(34)23(2,3)9-44-50(41,42)47-49(39,40)43-8-13-17(46-48(36,37)38)16(33)22(45-13)30-11-29-15-19(24)27-10-28-20(15)30/h10-11,13,16-18,22,33-34H,4-9H2,1-3H3,(H,25,32)(H,26,35)(H,39,40)(H,41,42)(H2,24,27,28)(H2,36,37,38)/t13-,16-,17-,18+,22-/m1/s1", "kegg.compound": "C00024"}}, {"id": "MALCOA", "name": "Malonyl coenzyme A", "compartment": "c", "charge": 0, "formula": "C24H38N7O19P3S", "notes": {"map_info": {"display_name": "Malonyl coenzyme A", "align": "center"}}, "annotation": {"chebi": "CHEBI:15531", "inchi": "InChI=1S/C24H38N7O19P3S/c1-24(2,19(37)22(38)27-4-3-13(32)26-5-6-54-15(35)7-14(33)34)9-47-53(44,45)50-52(42,43)46-8-12-18(49-51(39,40)41)17(36)23(48-12)31-11-30-16-20(25)28-10-29-21(16)31/h10-12,17-19,23,36-37H,3-9H2,1-2H3,(H,26,32)(H,27,38)(H,33,34)(H,42,43)(H,44,45)(H2,25,28,29)(H2,39,40,41)/t12-,17-,18-,19+,23-/m1/s1", "kegg.compound": "C00083"}}, {"id": "co2", "name": "Carbon dioxide", "compartment": "c", "charge": 0, "formula": "CO2", "notes": {"map_info": {"display_name": "CO2", "color": "#aec7e8"}}, "annotation": {"chebi": "CHEBI:16526", "inchi": "InChI=1S/CO2/c2-1-3", "kegg.compound": "C00011"}}, {"id": "coa", "name": "Coenzyme A", "compartment": "c", "charge": 0, "formula": "C21H36N7O16P3S", "notes": {"map_info": {"display_name": "COA", "color": "#A2CD5A"}}, "annotation": {"chebi": "CHEBI:15346", "inchi": "InChI=1S/C21H36N7O16P3S/c1-21(2,16(31)19(32)24-4-3-12(29)23-5-6-48)8-41-47(38,39)44-46(36,37)40-7-11-15(43-45(33,34)35)14(30)20(42-11)28-10-27-13-17(22)25-9-26-18(13)28/h9-11,14-16,20,30-31,48H,3-8H2,1-2H3,(H,23,29)(H,24,32)(H,36,37)(H,38,39)(H2,22,25,26)(H2,33,34,35)/t11-,14-,15-,16+,20-/m1/s1", "kegg.compound": "C00010"}}, {"id": "h2o", "name": "Water", "compartment": "c", "charge": 0, "formula": "H2O", "notes": {"map_info": {"display_name": "H2O", "color": "#FAEBD7"}}, "annotation": {"chebi": "CHEBI:15377", "inchi": "InChI=1S/H2O/h1H2", "kegg.compound": "C00001"}}, {"id": "nadp", "name": "NADP+", "compartment": "c", "charge": 0, "formula": "C21H28N7O17P3", "notes": {"map_info": {"display_name": "NADP", "color": "#CD9B1D"}}, "annotation": {"chebi": "CHEBI:18009", "inchi": "InChI=1S/C21H28N7O17P3/c22-17-12-19(25-7-24-17)28(8-26-12)21-16(44-46(33,34)35)14(30)11(43-21)6-41-48(38,39)45-47(36,37)40-5-10-13(29)15(31)20(42-10)27-3-1-2-9(4-27)18(23)32/h1-4,7-8,10-11,13-16,20-21,29-31H,5-6H2,(H7-,22,23,24,25,32,33,34,35,36,37,38,39)/p+1/t10-,11-,13-,14-,15-,16-,20-,21-/m1/s1", "kegg.compound": "C00006"}}, {"id": "nadph", "name": "NADPH", "compartment": "c", "charge": 0, "formula": "C21H30N7O17P3", "notes": {"map_info": {"display_name": "NADPH", "color": "#CD9B1D"}}, "annotation": {"chebi": "CHEBI:16474", "inchi": "InChI=1S/C21H30N7O17P3/c22-17-12-19(25-7-24-17)28(8-26-12)21-16(44-46(33,34)35)14(30)11(43-21)6-41-48(38,39)45-47(36,37)40-5-10-13(29)15(31)20(42-10)27-3-1-2-9(4-27)18(23)32/h1,3-4,7-8,10-11,13-16,20-21,29-31H,2,5-6H2,(H2,23,32)(H,36,37)(H,38,39)(H2,22,24,25)(H2,33,34,35)/t10-,11-,13-,14-,15-,16-,20-,21-/m1/s1", "kegg.compound": "C00005"}}, {"id": "MCRE", "name": "m-Cresol", "compartment": "c", "charge": 0, "formula": "C7H8O", "notes": {"map_info": {"display_name": "m-Cresol", "align": "center"}}, "annotation": {"chebi": "CHEBI:17231", "inchi": "InChI=1S/C7H8O/c1-6-3-2-4-7(8)5-6/h2-5,8H,1H3", "kegg.compound": "C01467"}}, {"id": "TOLU", "name": "Toluquinol", "compartmen ...
